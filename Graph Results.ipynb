# %% [markdown]
# Upload excel file - these values were taken from the results obtained from the actual analysis. The data file contains the chemical name, current UK spending in pounds, and projected UK spending in pounds.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 

data = pd.read_excel("values.xlsx")

# %% [markdown]
# We sort the data here by total spending for the purposes of making a clean graph

# %%
data = data.sort_values(by='Projected UK Spending in Pounds', ascending=False)

# %%
data.head(5)
# Out:
#         chemical  sum_cost_UK_pounds  Projected UK Spending in Pounds
# 0       Apixaban        2.069046e+08                     6.868052e+08
# 1    Rivaroxaban        1.801875e+08                     6.319583e+08
# 2    Sitagliptin        8.574411e+07                     4.640484e+08
# 4    Solifenacin        6.902248e+07                     3.584931e+08
# 10  Leuprorelin         3.634320e+07                     3.042621e+08

# %% [markdown]
# We graph data for actual and projected UK spending in USD for each chemical.

# %%
ind = np.arange(len(data))
width = 0.4

fig, ax = plt.subplots(figsize = (20, 20))
ax.barh(ind, data['Projected UK Spending in Pounds'], width, color='green', label='2018 Projected English Spending')
ax.barh(ind + width, data['sum_cost_UK_pounds'], width, color='blue', label='2018 English Spending')
opacity = 0.8

ax.set(yticks= ind + width, yticklabels=data['chemical'], ylim=[2*width - 1, len(data)])
ax.legend()
ax.set_xlabel('Spending, £ (100 million)')


plt.savefig('UK_US_price.pdf')
